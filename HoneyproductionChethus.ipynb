# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import plotly.express as px

import warnings
warnings.filterwarnings('ignore')

# %%
#importing dataset
hon=pd.read_csv('honeyproduction.csv')
hon
# Out:
#     state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0      AL   16000.0           71   1136000.0    159000.0        0.72
# 1      AZ   55000.0           60   3300000.0   1485000.0        0.64
# 2      AR   53000.0           65   3445000.0   1688000.0        0.59
# 3      CA  450000.0           83  37350000.0  12326000.0        0.62
# 4      CO   27000.0           72   1944000.0   1594000.0        0.70
# ..    ...       ...          ...         ...         ...         ...
# 621    VA    4000.0           41    164000.0     23000.0        3.77
# 622    WA   62000.0           41   2542000.0   1017000.0        2.38
# 623    WV    6000.0           48    288000.0     95000.0        2.91
# 624    WI   60000.0           69   4140000.0   1863000.0        2.05
# 625    WY   50000.0           51   2550000.0    459000.0        1.87
#
#       prodvalue  year
# 0      818000.0  1998
# 1     2112000.0  1998
# 2     2033000.0  1998
# 3    23157000.0  1998
# ...

# %%
#Checking first 15 rows
hon.head(15)
# Out:
#    state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0     AL   16000.0           71   1136000.0    159000.0        0.72
# 1     AZ   55000.0           60   3300000.0   1485000.0        0.64
# 2     AR   53000.0           65   3445000.0   1688000.0        0.59
# 3     CA  450000.0           83  37350000.0  12326000.0        0.62
# 4     CO   27000.0           72   1944000.0   1594000.0        0.70
# 5     FL  230000.0           98  22540000.0   4508000.0        0.64
# 6     GA   75000.0           56   4200000.0    307000.0        0.69
# 7     HI    8000.0          118    944000.0     66000.0        0.77
# 8     ID  120000.0           50   6000000.0   2220000.0        0.65
# 9     IL    9000.0           71    639000.0    204000.0        1.19
# 10    IN    9000.0           92    828000.0    489000.0        0.85
# 11    IA   50000.0           78   3900000.0   2301000.0        0.70
# 12    KS   16000.0           46    736000.0    390000.0        0.87
# ...

# %%
#Shape of data
hon.shape
# Out:
# (626, 8)

# %%
#Info of data
hon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 626 entries, 0 to 625
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   state        626 non-null    object
#  1   numcol       626 non-null    float64
#  2   yieldpercol  626 non-null    int64
#  3   totalprod    626 non-null    float64
#  4   stocks       626 non-null    float64
#  5   priceperlb   626 non-null    float64
#  6   prodvalue    626 non-null    float64
#  7   year         626 non-null    int64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 39.2+ KB

# %%
#Checking values for each year
hon.year.value_counts()
# Out:
# 2001    44
# 2002    44
# 2003    44
# 1998    43
# 1999    43
# 2000    43
# 2004    41
# 2005    41
# 2006    41
# 2007    41
# 2008    41
# 2009    40
# 2010    40
# 2011    40
# 2012    40
# Name: year, dtype: int64

# %%
#Plotting Pie Chart
plt.pie(hon.year.value_counts(),autopct=('%.1f%%'),radius=1.2,labels=[2001,2002,2003,1998,1999,2000,2004,2005,2006,2007,2008,2009,2010,2011,2012])
plt.show()

# %%
#Plot and Understand the distribution of the variable "price per lb" using displot

# %%
#Plotting Distplot for 'priceperlb'

sns.distplot(hon['priceperlb'],kde=True)
plt.show()

# %% [markdown]
# From the above plot,maximum price per pound for honey is 1.5 dollars,average price has ranged from 1.5-2 dollars

# %%
#Plotting Scatter plot for'numcol' and 'prodval'
x=hon['numcol']
y=hon['prodvalue']

plt.scatter(x,y)
plt.xlabel('numcol')
plt.ylabel('prodvalue')
plt.show()

# %% [markdown]
# From the above plot,the relationship between numcol(number of honey producing colonies) and
# prodvalue(Value of production (total prod x priceperlb)) is strong,positive,linear.

# %%
#Plot and understand the relationship between categorical variable 'year' and a numerical variable 'prodvalue'

# %%
sns.boxplot(x=hon['year'],y=hon['prodvalue'],data=hon)
plt.show()

# %% [markdown]
# From the above box plot,median production value for all years between (1998-2012) has ranged 0.5 dollars

# %%
#Visualize and understand the relationship between the multiple pairs of variables throughout 
#different years using pairplot and add your inferences. (use columns 'numcol', 'yield percol', 'total prod', 'prodvalue','year')

# %%
sns.pairplot(hon, hue='year', vars=['numcol', 'yieldpercol', 'totalprod', 'prodvalue','year'])
plt.show()

# %% [markdown]
# From the above pairplot,yeildpercol,numcol have normal distribution

# %%
hon2=hon.drop(['state'],axis=1)
corr=hon2.corr()
corr
# Out:
#                numcol  yieldpercol  totalprod    stocks  priceperlb  \
# numcol       1.000000     0.243515   0.953594  0.825929   -0.232701
# yieldpercol  0.243515     1.000000   0.396252  0.367812   -0.358646
# totalprod    0.953594     0.396252   1.000000  0.878830   -0.264499
# stocks       0.825929     0.367812   0.878830  1.000000   -0.305867
# priceperlb  -0.232701    -0.358646  -0.264499 -0.305867    1.000000
# prodvalue    0.912796     0.278977   0.907236  0.728560   -0.089567
# year         0.008709    -0.232092  -0.055556 -0.119602    0.693984
#
#              prodvalue      year
# numcol        0.912796  0.008709
# yieldpercol   0.278977 -0.232092
# totalprod     0.907236 -0.055556
# stocks        0.728560 -0.119602
# priceperlb   -0.089567  0.693984
# prodvalue     1.000000  0.139451
# year          0.139451  1.000000

# %%
sns.heatmap(corr,annot=True,cmap="crest")
plt.show()

# %% [markdown]
# From the above plot,numcol and totalprod are highly correlated and have a strong relationship
